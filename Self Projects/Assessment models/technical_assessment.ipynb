# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEmbeddings, HuggingFaceEndpoint
from langchain_core.messages import AIMessage, HumanMessage, ToolMessage, ChatMessage
from langchain_community.document_loaders import PyPDFLoader
from langchain_core.output_parsers import StrOutputParser, JsonOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from dotenv import load_dotenv
import json
import os

# %%
load_dotenv()

hf_api_key = os.getenv('HUGGINGFACEHUB_ACCESS_TOKEN')

# %%
llm = HuggingFaceEndpoint(
    model="mistralai/Mistral-7B-Instruct-v0.2",
    task="text-generation",
    huggingfacehub_api_token=hf_api_key,
    temperature=0.5
)

model = ChatHuggingFace(llm=llm)

# %%
parser1 = StrOutputParser()
parser2 = JsonOutputParser()

# %%
resume_loader1 = PyPDFLoader("./data/Krishil Agrawal Resume - ML.pdf")
resume_loader2 = PyPDFLoader("./data/Krishil Agrawal Resume - Web.pdf")

resume1 = resume_loader1.load()
resume2 = resume_loader2.load()

# %%
print(resume2[0].page_content)
# Out:
# KRISHIL AGRAWAL
# krishilagrawal026@gmail.com | +91 8320902499  | www.linkedin.com/in/krishil-agrawal-49aaa9283
#
# Education
#
#
# Charusat University of Gujarat, India                                                                                                                2023 - 2027
# ● Computer Science & Engineering | CGPA: 9.29
# Shannen School, India                                                                      2022 - 2023
# ● Class XII,Percentile: 98.02
# ● GUJCET: 97.71
# Shannen School, India                                                          2020 - 2021
# ● Class X,Percentile: 98.35
#
# Skills
#
#
# • Languages: Python, C++, Java (Basics)
# • Web Technologies: HTML, CSS, JavaScript, React, Tailwind CSS
# • Libraries/Frameworks: GSAP, Locomotive Scroll, Shadcn UI
# • Tools: Git, GitHub, VS Code, Vite, npm
# • Programming: Python (Basics), C++ (Basics)
# • Databases: MySQL (Basics), MonogoDB
# • Tools & Platforms: Git, GitHub, VS Code, Postman, Figma
# • Soft Skills: Problem-Solving, Team Collaboration, Analytical Thinking, Time Management
#
# Projects
#
# Personal Portfolio Website
#
# • Designed and developed a fully responsive personal portfolio website to showcase skills, projects, and achievements.
# • Implemented clean UI/UX with HTML, CSS, and JavaScript, ensuring cross-browser compatibility and mobile
# optimization.
# • Hosted the site using GitHub Pages for easy access and version control.
# • Tools: HTML, CSS, JavaScript, Git, GitHub Pages.
#
# Hostel Management Website
#
# • Built a web application to streamline hostel operations, including room allocation and student registration features.
# • Created an intuitive front-end with HTML and CSS, paired with basic JavaScript for form validation and interactivity.
# • Integrated a simple backend using [e.g., Node.js or PHP, if applicable; adjust based on your tech] for data
# management.
# • Tools: HTML, CSS, JavaScript, [Add backend tool if used, e.g., Node.js, MySQL]
#
# Ochi Website with Animations
#
# • Developed a visually engaging website inspired by modern design trends using React and animation libraries like
# GSAP and Locomotive Scroll.
# • Utilized Shadcn UI for reusable components and enhanced user experience with smooth scrolling and transitions.
# • Optimized performance and ensured responsiveness across devices with Tailwind CSS.
# • Tools: React, JavaScript, GSAP, Locomotive Scroll, Shadcn UI, Tailwind CSS, Vite
#
# Academic and Extracurricular Achievements
#
#
# • Selected for Indus Valley Hackathon 2024, showcasing innovation and teamwork.
# • Ranked in Top 3 academically in two semesters at CHARUSAT University.
# • Secured 98th percentile and topped the batch in both 10th and 12th board examinations.
# • Volunteer in organizing tech workshops for peers.
# • Active participant in university coding clubs and hackathons.

# %%
# skill_extract_template = """ Analyze the whole resume and extract all the technical skills mentioned in the {resume} """

# question_generate_template = """
# Based on the following technical skills: {skills}

# Generate 20 technical assessment questions to evaluate a candidate's proficiency in these skills. Each question should be clear, relevant to the skills, and suitable for a technical interview or assessment. Format the output as a numbered list.
# """

# %%
template1 = PromptTemplate(
  template="Analyze the whole resume and extract all the technical skills mentioned in the {resume1}",
  input_variables=['resume1']
)

template2 = PromptTemplate(
  template="You have given a list of technical skills now generate 20 intermediate level mcqs from the {skills} with the right answer written after the option. Give output as a dictionary containing the question, options and answers: \n {format_instruction}",
  input_variables=['level', 'technical_skills'],
  partial_variables={'format_instruction': parser2.get_format_instructions() }
)

# %%
chain = template1 | model | parser1 | template2 | model | parser2

# %%
result = chain.invoke({'resume1': resume1 })
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_core\output_parsers\json.py:82, in JsonOutputParser.parse_result(self, result, partial)
#      81 try:
# ---> 82     return parse_json_markdown(text)
#      83 except JSONDecodeError as e:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_core\utils\json.py:150, in parse_json_markdown(json_string, parser)
#     149     json_str = json_string if match is None else match.group(2)
# --> 150 return _parse_json(json_str, parser=parser)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_core\utils\json.py:166, in _parse_json(json_str, parser)
#     165 # Parse the JSON string into a Python dictionary
# --> 166 return parser(json_str)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_core\utils\json.py:123, in parse_partial_json(s, strict)
#     120 # If we got here, we ran out of characters to remove
#     121 # and still couldn't parse the string as JSON, so return the parse error
#     122 # for the original string.
# --> 123 return json.loads(s, strict=strict)
#
# File c:\Users\Krishil Agrawal\anaconda3\Lib\json\__init__.py:359, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     358     kw['parse_constant'] = parse_constant
# --> 359 return cls(**kw).decode(s)
#
# File c:\Users\Krishil Agrawal\anaconda3\Lib\json\decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     341 """Return the Python representation of ``s`` (a ``str`` instance
#     342 containing a JSON document).
#     343
#     344 """
# --> 345 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346 end = _w(s, end).end()
#
# File c:\Users\Krishil Agrawal\anaconda3\Lib\json\decoder.py:361, in JSONDecoder.raw_decode(self, s, idx)
#     360 try:
# --> 361     obj, end = self.scan_once(s, idx)
#     362 except StopIteration as err:
#
# JSONDecodeError: Invalid \escape: line 59 column 18 (char 2751)
#
# The above exception was the direct cause of the following exception:
#
# OutputParserException                     Traceback (most recent call last)
# Cell In[274], line 1
# ----> 1 result = chain.invoke({'resume1': resume1 })
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_core\runnables\base.py:3047, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3045                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046             else:
# -> 3047                 input_ = context.run(step.invoke, input_, config)
#    3048 # finish the root run
#    3049 except BaseException as e:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_core\output_parsers\base.py:196, in BaseOutputParser.invoke(self, input, config, **kwargs)
#     188 @override
#     189 def invoke(
#     190     self,
#    (...)
#     193     **kwargs: Any,
#     194 ) -> T:
#     195     if isinstance(input, BaseMessage):
# --> 196         return self._call_with_config(
#     197             lambda inner_input: self.parse_result(
#     198                 [ChatGeneration(message=inner_input)]
#     199             ),
#     200             input,
#     201             config,
#     202             run_type="parser",
#     203         )
#     204     return self._call_with_config(
#     205         lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     206         input,
#     207         config,
#     208         run_type="parser",
#     209     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_core\runnables\base.py:1940, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    1936     child_config = patch_config(config, callbacks=run_manager.get_child())
#    1937     with set_config_context(child_config) as context:
#    1938         output = cast(
#    1939             "Output",
# -> 1940             context.run(
#    1941                 call_func_with_variable_args,  # type: ignore[arg-type]
#    1942                 func,
#    1943                 input_,
#    1944                 config,
#    1945                 run_manager,
#    1946                 **kwargs,
#    1947             ),
#    1948         )
#    1949 except BaseException as e:
#    1950     run_manager.on_chain_error(e)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_core\runnables\config.py:428, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     426 if run_manager is not None and accepts_run_manager(func):
#     427     kwargs["run_manager"] = run_manager
# --> 428 return func(input, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_core\output_parsers\base.py:197, in BaseOutputParser.invoke.<locals>.<lambda>(inner_input)
#     188 @override
#     189 def invoke(
#     190     self,
#    (...)
#     193     **kwargs: Any,
#     194 ) -> T:
#     195     if isinstance(input, BaseMessage):
#     196         return self._call_with_config(
# --> 197             lambda inner_input: self.parse_result(
#     198                 [ChatGeneration(message=inner_input)]
#     199             ),
#     200             input,
#     201             config,
#     202             run_type="parser",
#     203         )
#     204     return self._call_with_config(
#     205         lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     206         input,
#     207         config,
#     208         run_type="parser",
#     209     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_core\output_parsers\json.py:85, in JsonOutputParser.parse_result(self, result, partial)
#      83 except JSONDecodeError as e:
#      84     msg = f"Invalid json output: {text}"
# ---> 85     raise OutputParserException(msg, llm_output=text) from e
#
# OutputParserException: Invalid json output: [
# {"question": "Which of the following programming languages did the candidate mention having a basic understanding of?",
# "options": ["Ruby", "Swift", "Java", "Python"],
# "answer": "Java"},
#
# {"question": "Which machine learning technique falls under the category of supervised learning?",
# "options": ["Random Forest", "K-means Clustering", "Regression", "Neural Networks"],
# "answer": "Regression"},
#
# {"question": "Which data science tool is commonly used for data manipulation and data framing?",
# "options": ["NumPy", "Pandas", "Scikit-learn", "Matplotlib"],
# "answer": "Pandas"},
#
# {"question": "Which machine learning technique is typically used for exploratory data analysis and pattern identification?",
# "options": ["Supervised Learning", "Unsupervised Learning", "SVM", "Naive Bayes"],
# "answer": "Unsupervised Learning"},
#
# {"question": "Which version control system was mentioned in the resume?",
# "options": ["Microsoft Team Foundation Server", "Perforce", "Git", "Bitbucket"],
# "answer": "Git"},
#
# {"question": "Which machine learning model is used when the desired output is a probability estimation?",
# "options": ["Decision Tree", "K-Nearest Neighbors", "Logistic Regression", "SVM"],
# "answer": "Logistic Regression"},
#
# {"question": "Which of the following DBMS was mentioned in the resume?",
# "options": ["Oracle", "MS SQL Server", "MongoDB", "MySQL"],
# "answer": "MySQL"},
#
# {"question": "In Machine Learning, which technique is used to inspect the relationships among variables?",
# "options": ["Supervised Learning", "Unsupervised Learning", "Feature Scaling", "Feature Engineering"],
# "answer": "Feature Engineering"},
#
# {"question": "Which data science library is used for building predictive models?",
# "options": ["NumPy", "Pandas", "Scikit-learn", "Matplotlib"],
# "answer": "Scikit-learn"},
#
# {"question": "Which tool is used for designing user interfaces?",
# "options": ["Figma", "Blender", "Sublime Text", "Visual Studio Code"],
# "answer": "Figma"},
#
# {"question": "Which ML model is used for clustering algorithm?",
# "options": ["SVM", "Naive Bayes", "Decision Trees", "K-means"],
# "answer": "K-means"},
#
# {"question": "Which of the following is not a data science tool mentioned in the resume?",
# "options": ["TensorFlow", "Pandas", "Scikit-learn", "Tableau"],
# "answer": "Tableau"},
#
# {"question": "Which database is a document-oriented database mentioned in the resume?",
# "options": ["Oracle", "MySQL", "MongoDB", "SQLite"],
# "answer": "MongoDB"},
#
# {"question": "Which of the following IDE is mentioned in the resume?",
# "options": ["Eclipse", "IntelliJ IDEA", "PyCharm", "Visual Studio Code"],
# "answer": "Visual Studio Code"},
#
#  {"question": "Which ML model is used when the output variable depends on multiple independent variables?",
#  "options": ["SVM\[Support Vector Machines\]", "K-Nearest Neighbors\[KNN\]", "Logistic Regression", "Decision Trees"],
#  "answer": "Logistic Regression"},
#
#  {"question": "Which ML algorithm can be used for solving regression problems?",
#  "options": ["SVM", "Neural Networks", "Regression", "Random Forest"],
#  "answer": "Regression"},
#
#  {"question": "Which tool can be used to test APIs?",
#  "options": ["GitHub", " Jenkins", "Postman", "Selenium"],
#  "answer": "Postman"}
# ]
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE

# %%
print(result)
print(type(result))
# Out:
# {'MCQ_1': {'Question': 'Which programming language is used for building machine learning models?', 'Options': ['Python', 'C++', 'Java'], 'Answer': 'Python'}, 'MCQ_2': {'Question': 'Which machine learning technique is used for making a model learn from labeled data?', 'Options': ['Unsupervised Learning', 'Supervised Learning', 'Regression'], 'Answer': 'Supervised Learning'}, 'MCQ_3': {'Question': 'Which NumPy function does one use to check the shape of an array?', 'Options': ['numba()', 'np.shape()', 'np.size()'], 'Answer': 'np.shape()'}, 'MCQ_4': {'Question': 'Which tool is used for version control of code locally?', 'Options': ['GitHub', 'Git', 'VS Code'], 'Answer': 'Git'}, 'MCQ_5': {'Question': 'Which machine learning algorithm is used for regression analysis?', 'Options': ['Naive Bayes', 'Decision Trees', 'Random Forest', 'Linear Regression'], 'Answer': 'Linear Regression'}, 'MCQ_6': {'Question': 'Which MongoDB command is used to insert a document into a collection?', 'Options': ['update()', 'insert()', 'find()'], 'Answer': 'insert()'}, 'MCQ_7': {'Question': 'Which data science technique is used for reducing the number of features in a dataset?', 'Options': ['Supervised Learning', 'Unsupervised Learning', 'Feature Scaling', 'Feature Engineering'], 'Answer': 'Feature Engineering'}, 'MCQ_8': {'Question': 'Which machine learning algorithm is used for splitting data into two or more classes?', 'Options': ['Linear Regression', 'Random Forest', 'Regression', 'Decision Trees'], 'Answer': 'Decision Trees'}, 'MCQ_9': {'Question': 'Which pandas function does one use to filter rows in a DataFrame based on condition?', 'Options': ['apply()', 'head()', 'describe()', 'filter()'], 'Answer': 'query()'}, 'MCQ_10': {'Question': 'Which Jupyter Notebook extension is used for designing user interfaces?', 'Options': ['VanillaJS', 'HTML/CSS', 'Figma', 'Git'], 'Answer': 'Figma'}, 'MCQ_11': {'Question': 'Which NumPy function is used for reshaping the arrays into desired shapes?', 'Options': ['transpose()', 'reshape()', 'sum()'], 'Answer': 'reshape()'}, 'MCQ_12': {'Question': 'Which machine learning technique is used to identify hidden patterns from unlabeled data?', 'Options': ['Supervised Learning', 'Unsupervised Learning', 'Regression'], 'Answer': 'Unsupervised Learning'}, 'MCQ_13': {'Question': 'Which database management system is used for MySQL-based web applications?', 'Options': ['PostgreSQL', 'OracleDB', 'MongoDB', 'MySQL'], 'Answer': 'MySQL'}, 'MCQ_14': {'Question': 'Which Python library is used for building RESTful APIs?', 'Options': ['Scikit-learn', 'Pandas', 'Django', 'Flask'], 'Answer': 'Django'}, 'MCQ_15': {'Question': 'Which machine learning algorithm is used for cluster analysis?', 'Options': ['Decision Trees', 'Naive Bayes', 'Random Forest', 'K-Means'], 'Answer': 'K-Means'}, 'MCQ_16': {'Question': 'Which tool is used for sending HTTP requests?', 'Options': ['Postman', 'figma', 'git', 'VS Code'], 'Answer': 'Postman'}, 'MCQ_17': {'Question': 'Which ML library is used for performing matrix operations on data?', 'Options': ['Pandas', 'NumPy', 'Scikit-learn', 'Matplotlib'], 'Answer': 'NumPy'}, 'MCQ_18': {'Question': 'Which machine learning algorithm is used for anomaly detection?', 'Options': ['Naive Bayes', 'Decision Trees', 'Random Forest', 'Isolation Forests'], 'Answer': 'Isolation Forests'}, 'MCQ_19': {'Question': 'Which programming language is commonly used for building web applications?', 'Options': ['Python', 'C++', 'Java'], 'Answer': 'Python'}, 'MCQ_20': {'Question': 'Which data visualization library is used for creating informative and attractive data visualizations?', 'Options': ['Matplotlib', 'Pandas', 'Seaborn', 'NumPy'], 'Answer': 'Seaborn'}}
# <class 'dict'>

# %%
result
# Out:
# {'MCQ_1': {'Question': 'Which programming language is used for building machine learning models?',
#   'Options': ['Python', 'C++', 'Java'],
#   'Answer': 'Python'},
#  'MCQ_2': {'Question': 'Which machine learning technique is used for making a model learn from labeled data?',
#   'Options': ['Unsupervised Learning', 'Supervised Learning', 'Regression'],
#   'Answer': 'Supervised Learning'},
#  'MCQ_3': {'Question': 'Which NumPy function does one use to check the shape of an array?',
#   'Options': ['numba()', 'np.shape()', 'np.size()'],
#   'Answer': 'np.shape()'},
#  'MCQ_4': {'Question': 'Which tool is used for version control of code locally?',
#   'Options': ['GitHub', 'Git', 'VS Code'],
#   'Answer': 'Git'},
#  'MCQ_5': {'Question': 'Which machine learning algorithm is used for regression analysis?',
#   'Options': ['Naive Bayes',
#    'Decision Trees',
#    'Random Forest',
#    'Linear Regression'],
#   'Answer': 'Linear Regression'},
#  'MCQ_6': {'Question': 'Which MongoDB command is used to insert a document into a collection?',
#   'Options': ['update()', 'insert()', 'find()'],
#   'Answer': 'insert()'},
#  'MCQ_7': {'Question': 'Which data science technique is used for reducing the number of features in a dataset?',
#   'Options': ['Supervised Learning',
#    'Unsupervised Learning',
#    'Feature Scaling',
#    'Feature Engineering'],
#   'Answer': 'Feature Engineering'},
#  'MCQ_8': {'Question': 'Which machine learning algorithm is used for splitting data into two or more classes?',
#   'Options': ['Linear Regression',
#    'Random Forest',
#    'Regression',
#    'Decision Trees'],
#   'Answer': 'Decision Trees'},
#  'MCQ_9': {'Question': 'Which pandas function does one use to filter rows in a DataFrame based on condition?',
#   'Options': ['apply()', 'head()', 'describe()', 'filter()'],
#   'Answer': 'query()'},
#  'MCQ_10': {'Question': 'Which Jupyter Notebook extension is used for designing user interfaces?',
#   'Options': ['VanillaJS', 'HTML/CSS', 'Figma', 'Git'],
#   'Answer': 'Figma'},
#  'MCQ_11': {'Question': 'Which NumPy function is used for reshaping the arrays into desired shapes?',
#   'Options': ['transpose()', 'reshape()', 'sum()'],
#   'Answer': 'reshape()'},
#  'MCQ_12': {'Question': 'Which machine learning technique is used to identify hidden patterns from unlabeled data?',
#   'Options': ['Supervised Learning', 'Unsupervised Learning', 'Regression'],
#   'Answer': 'Unsupervised Learning'},
#  'MCQ_13': {'Question': 'Which database management system is used for MySQL-based web applications?',
#   'Options': ['PostgreSQL', 'OracleDB', 'MongoDB', 'MySQL'],
#   'Answer': 'MySQL'},
#  'MCQ_14': {'Question': 'Which Python library is used for building RESTful APIs?',
#   'Options': ['Scikit-learn', 'Pandas', 'Django', 'Flask'],
#   'Answer': 'Django'},
#  'MCQ_15': {'Question': 'Which machine learning algorithm is used for cluster analysis?',
#   'Options': ['Decision Trees', 'Naive Bayes', 'Random Forest', 'K-Means'],
#   'Answer': 'K-Means'},
#  'MCQ_16': {'Question': 'Which tool is used for sending HTTP requests?',
#   'Options': ['Postman', 'figma', 'git', 'VS Code'],
#   'Answer': 'Postman'},
#  'MCQ_17': {'Question': 'Which ML library is used for performing matrix operations on data?',
#   'Options': ['Pandas', 'NumPy', 'Scikit-learn', 'Matplotlib'],
#   'Answer': 'NumPy'},
#  'MCQ_18': {'Question': 'Which machine learning algorithm is used for anomaly detection?',
#   'Options': ['Naive Bayes',
#    'Decision Trees',
#    'Random Forest',
#    'Isolation Forests'],
#   'Answer': 'Isolation Forests'},
#  'MCQ_19': {'Question': 'Which programming language is commonly used for building web applications?',
#   'Options': ['Python', 'C++', 'Java'],
#   'Answer': 'Python'},
#  'MCQ_20': {'Question': 'Which data visualization library is used for creating informative and attractive data visualizations?',
#   'Options': ['Matplotlib', 'Pandas', 'Seaborn', 'NumPy'],
#   'Answer': 'Seaborn'}}

# %%
print(result['MCQ_1'])
print(result['MCQ_1']['Question'])
# Out:
# {'Question': 'Which programming language is used for building machine learning models?', 'Options': ['Python', 'C++', 'Java'], 'Answer': 'Python'}
# Which programming language is used for building machine learning models?

# %%
questions = []
answers = []
options = []
for mcq_key in result:
    question = result[mcq_key]['Question']
    answer = result[mcq_key]["Answer"]
    option = result[mcq_key]["Options"]
    questions.append(question)
    answers.append(answer)
    options.append(option)

# %%
options
# Out:
# [['Python', 'C++', 'Java'],
#  ['Unsupervised Learning', 'Supervised Learning', 'Regression'],
#  ['numba()', 'np.shape()', 'np.size()'],
#  ['GitHub', 'Git', 'VS Code'],
#  ['Naive Bayes', 'Decision Trees', 'Random Forest', 'Linear Regression'],
#  ['update()', 'insert()', 'find()'],
#  ['Supervised Learning',
#   'Unsupervised Learning',
#   'Feature Scaling',
#   'Feature Engineering'],
#  ['Linear Regression', 'Random Forest', 'Regression', 'Decision Trees'],
#  ['apply()', 'head()', 'describe()', 'filter()'],
#  ['VanillaJS', 'HTML/CSS', 'Figma', 'Git'],
#  ['transpose()', 'reshape()', 'sum()'],
#  ['Supervised Learning', 'Unsupervised Learning', 'Regression'],
#  ['PostgreSQL', 'OracleDB', 'MongoDB', 'MySQL'],
#  ['Scikit-learn', 'Pandas', 'Django', 'Flask'],
#  ['Decision Trees', 'Naive Bayes', 'Random Forest', 'K-Means'],
#  ['Postman', 'figma', 'git', 'VS Code'],
#  ['Pandas', 'NumPy', 'Scikit-learn', 'Matplotlib'],
#  ['Naive Bayes', 'Decision Trees', 'Random Forest', 'Isolation Forests'],
#  ['Python', 'C++', 'Java'],
#  ['Matplotlib', 'Pandas', 'Seaborn', 'NumPy']]
