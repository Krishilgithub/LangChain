# %%
import os

# %%
from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace
from dotenv import load_dotenv

load_dotenv()
hf_api_key = os.getenv('HUGGINGFACEHUB_ACCESS_TOKEN')

llm = HuggingFaceEndpoint(
    model="mistralai/Mistral-7B-Instruct-v0.2",
    task="text-generation",
    huggingfacehub_api_token=hf_api_key
)

model = ChatHuggingFace(
    llm=llm,
    model_kwargs={
        "temperature": 0.5,
    }
)

# %%
# from youtube_transcript_api import YoutubeTranscriptApi, TranscriptDisabled
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate

# %%
pip install youtube_transcript_api
# Out:
# Collecting youtube_transcript_api
#   Downloading youtube_transcript_api-1.1.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in c:\users\krishil agrawal\anaconda3\lib\site-packages (from youtube_transcript_api) (0.7.1)
# Requirement already satisfied: requests in c:\users\krishil agrawal\appdata\roaming\python\python313\site-packages (from youtube_transcript_api) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\krishil agrawal\appdata\roaming\python\python313\site-packages (from requests->youtube_transcript_api) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\krishil agrawal\appdata\roaming\python\python313\site-packages (from requests->youtube_transcript_api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\krishil agrawal\appdata\roaming\python\python313\site-packages (from requests->youtube_transcript_api) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\krishil agrawal\appdata\roaming\python\python313\site-packages (from requests->youtube_transcript_api) (2025.6.15)
# Downloading youtube_transcript_api-1.1.1-py3-none-any.whl (485 kB)
# Installing collected packages: youtube_transcript_api
# Successfully installed youtube_transcript_api-1.1.1
# Note: you may need to restart the kernel to use updated packages.
